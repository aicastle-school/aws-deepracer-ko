# %% [markdown]
# # 보상함수의 입력 파라미터 (params)

# %% [markdown]
# <p style="display: flex; justify-content: space-between; align-items: center;">
#     <b>Unit 02. 보상함수의 입력 파라미터</b>
#     <span><b>Section 08. 보상 함수</b></span>
# </p>

# %% [markdown]
# ---
# <h3 style="display: flex; justify-content: space-between; align-items: center;">
#     PPT
#     <span style="font-size: 0.6em;">
#         <a href="" target="_blank">🔗 Link </a>
#     </span>
# </h3>

# %% [markdown]
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https:&#x2F;&#x2F;www.canva.com&#x2F;design&#x2F;DAFaa5xryzo&#x2F;view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>

# %% [markdown]
# ---
# <h3 style="display: flex; justify-content: space-between; align-items: center;">
#     Video
#     <span style="font-size: 0.7em;">
#         <a href="../premium/01.html" target="_blank" title="이 영상은 프리미엄 과정에 등록된 계정에서만 볼 수 있습니다">🚀 프리미엄 과정 </a>
#     </span>
#     <span style="font-size: 0.6em;">
#         <a href="" title="인프런에서도 이 영상을 시청할 수 있습니다"><img src="https://cdn.inflearn.com/public/users/thumbnails/234401/660102d4-1e7b-4c43-a7ba-7d0ee6d96b83" height="14px" style="vertical-align: middle; padding-right: 3px;"> 인프런</a> |
#         <a href="" target="_blank">🔗 Link </a>
#     </span>
# </h3>

# %% [markdown]
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://drive.google.com/file/d/11XSCqGhSAj-SlCNSdDLeuv-065jtBKvD/preview"
#     allowfullscreen="allowfullscreen"
#     allow="fullscreen">
#   </iframe>
# </div>

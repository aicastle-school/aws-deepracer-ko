# %% [markdown]
# # 프리미엄 과정 🚀

# %% [markdown]
# ## 기본 vs 프리미엄
#
# ||기본 🆓|프리미엄 🚀|
# |---|:-----:|:-----:|
# |**PPT**|⭕|⭕|
# |**Video**|❌|⭕|
# |**Q&A**|❌|⭕|

# %% [markdown]
# - 비디오의 총 분량은 **약 6시간**입니다. (<a href="05.html">비디오 미리보기</a>)
# - PPT 와 Video는 뷰어로 제공.
# - `Q&A`는 동영상에 댓글달기를 통해 질문할 수 있습니다.
# -

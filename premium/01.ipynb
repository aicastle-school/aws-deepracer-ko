# %% [markdown]
# # 출강 및 프리미엄 과정 🚀

# %% [markdown]
# ## 출강 위탁교육 및 행사 대행 안내
#
# - (주)에이아이캐슬에는 AWS DeepRacer School 교육과정으로 출강 위탁교육 및 행사 대행업무를 진행하고 있습니다.
# - 안내 링크 : <https://edu-deepracer.my.canva.site/>

# %% [markdown]
# ## 기본 vs 프리미엄
#
# ||기본 🆓|프리미엄 🚀|
# |---|:-----:|:-----:|
# |**PPT**|⭕|⭕|
# |**Video**|❌|⭕|
# |**Q&A**|❌|⭕|

# %% [markdown]
# - PPT 와 Video는 뷰어로 제공되며 다운로드는 제공하지 않습니다.
# - `Q&A`는 동영상에 댓글달기를 통해 질문할 수 있습니다.
